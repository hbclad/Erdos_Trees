# %% [markdown]
# ## Dataset Construction
# The following Notebook contains the code used for constructing our final dataset. This dataset is a combonation of the WA_TREE and WA_PLOT dataset accessed via the USFS FIA Datamart. The following sections will outline the data combonation algorithm and sanity checks done on the data to make sure it's fully valid and properly copied. We are aiming to keep the LAT, LON, MEASYEAR, MEASMON, MEASDAY from the WA_PLOT dataset in order to understand where our trees/forests are located and how they've been impacted by fires.
#
# ### Algorithm
# We plan to combine the datasets along the column axes 'CN' from the WA_PLOT data and 'PLT_CN' from WA_TREE's since these are the two unique identifiers for each plot. We do this by using `pd.merge()` with WA_PLOT on the left and WA_TREE on the right, via the `left_on` and `right_on` arguments for alignment. This will additionally copy over LAT & LON values to all PLT_CN values were CN has a a LAT & LON. This will result in some dulicates given that there are duplicate years. Further documentation on `pd.merge` can be found at: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html
#
# ### Sanity Checks
# After the merge, all variables except those in the merge will be dropped and some sanity checks will be performed. Once sanity checks are passed, mostly checking that all LAT and LON carried over, we'll drop all variables that are non-essantial from the main dataset, such as variables not realated to our study, location, or duplicates from the merge. A full list of these will be given when it's done in the nb.
#
# ### Saving Final Dataset
# The final dataset, after all un-needed variables have been dropped will be exported to a .csv file that will be zipped and uploaded to the group Github for all to use and manipulate.

# %% [markdown]
# **WARNING: Do not attempt to plot all 500000+ values of this final dataset as a map. It WILL crash VSCode. I have yet to figure out a way around it**

# %%
import pandas as pd
import numpy as np

# %%
trees = pd.read_csv('/Users/ellapalacios/Downloads/tree_proj/data/WA_TREE.csv')
plots = pd.read_csv('/Users/ellapalacios/Downloads/tree_proj/data/WA_PLOT.csv')
# Out:
# /var/folders/nk/f27c2wr95rxdlns7bpdhxv680000gn/T/ipykernel_52090/380277768.py:1: DtypeWarning: Columns (77,159) have mixed types. Specify dtype option on import or set low_memory=False.
#   trees = pd.read_csv('/Users/ellapalacios/Downloads/tree_proj/data/WA_TREE.csv')

# %%
#reducing data from WA_PLOT to only what we need

plots = plots[['CN', 'PLOT', 'INVYR', 'COUNTYCD', 'LAT', 'LON', 'ELEV', 'MEASYEAR', 'MEASMON', 'MEASDAY']] #takes this down to 1.7MB file instead of 11.6.

# %%
#sorting each dataframe before combonation 

plots = plots.sort_values(by = 'CN')
trees  = trees.sort_values(by = 'PLT_CN')

# %%
#merging to create new dataset

new_data = pd.merge(plots, trees, left_on= 'CN', right_on= 'PLT_CN')

# %%
#creating sanity check from just what we need to check from new_data

sanity_check_data = new_data[['CN_x', 'PLT_CN', 'PLOT_x', 'PLOT_y', 'COUNTYCD_x', 'COUNTYCD_y', 'INVYR_x', 'INVYR_y' ]]

# %%
sanity_check_data.head(-5) #look at the top and bottom 5 rows to check for matching values across the board.
# Out:
#                    CN_x           PLT_CN  PLOT_x  PLOT_y  COUNTYCD_x  \
# 0                 21116            21116       3       3           9
# 1                 21116            21116       3       3           9
# 2                 21116            21116       3       3           9
# 3                 21116            21116       3       3           9
# 4                 21116            21116       3       3           9
# ...                 ...              ...     ...     ...         ...
# 504946  786780595290487  786780595290487   82332   82332           3
# 504947  786780595290487  786780595290487   82332   82332           3
# 504948  786780595290487  786780595290487   82332   82332           3
# 504949  786780595290487  786780595290487   82332   82332           3
# 504950  786780595290487  786780595290487   82332   82332           3
#
#         COUNTYCD_y  INVYR_x  INVYR_y
# 0                9     2001     2001
# 1                9     2001     2001
# 2                9     2001     2001
# 3                9     2001     2001
# 4                9     2001     2001
# ...            ...      ...      ...
# 504946           3     2021     2021
# 504947           3     2021     2021
# 504948           3     2021     2021
# 504949           3     2021     2021
# 504950           3     2021     2021
#
# [504951 rows x 8 columns]

# %%
#testing using a pandas.testing function
from pandas.testing import assert_frame_equal

frame1 = sanity_check_data[['CN_x',  'PLOT_x', 'COUNTYCD_x', 'INVYR_x']]
frame2 = sanity_check_data[[ 'PLT_CN',  'PLOT_y', 'COUNTYCD_y', 'INVYR_y' ]]

frame1 = frame1.rename(columns={'CN_x':'CN', 'PLOT_x': 'PLOT', 'COUNTYCD_x':'COUNTYCD', 'INVYR_x' :'INVYR'})
frame2 = frame2.rename(columns={'PLT_CN':'CN', 'PLOT_y': 'PLOT', 'COUNTYCD_y':'COUNTYCD', 'INVYR_y' :'INVYR'})

assert_frame_equal(frame1, frame2, check_dtype= False ) #note: for this not to return an error, the columns MUST have the same names in each dataframe. 

#this returning nothing means they do infact line up. Assertion == passed :)

# %% [markdown]
# With the sanity check passed, we can move on to dropping un-needed features (columns) and saving the file as a.csv .

# %%
#dropping unnecessary features 
final_data = new_data.drop(columns= ['PREV_ACTUALHT_FLD', 'PREV_HT_FLD' ])

# %% [markdown]
# List of dropped columns (with def) from `new_data`.
# + STATECD == state code.
# + xx_NERS == Has to do with North East Research Station, does not apply to our region.
# + xx_SRS == data from South Research Station, does not apply to our region.
# + xx_NCRS == data from North Central Research Station, does not apply to our region.
# + xx_RMRS == data from Rocky Mountian Research Station, does not apply to our region.
# + VOLCSSND == Sound cubic-foot wood volume in the sawlog portion of a sawtimber tree.
# + DRYBIO_SAWLOG == Dry biomass of wood in the sawlog portion of a sawtimber tree.
# + ACTUALHT_CALC_CD == Actual height, calculated, code.
# + CULL_BF_ROTTEN == Rotten/missing board-foot cull of the sawlog.
# + CULL_BF_ROTTEN_CD == Rotten/missing board-foot cull of the sawlog code.
# + CULL_BF_ROUGH ==
# + CULL_BF_ROUGH_CD ==
# + VOLBSGRS == Gross board-foot wood volume in the sawlog portion of a sawtimber tree (Scribner
# Rule).
# + VOLBSNET ==
# + CULTURALLY_KILLED_PNWRS ==
# + GST_PNWRS ==
# + VOLTSSND ==
# + VOLCFGRS_BARK ==
# + VOLCFGRS_TOP ==
# + VOLCFGRS_TOP_BARK ==
# + PREV_ACTUAL_HT_FLD ==
# + PREV_HT_FLD ==

# %%
pd.options.display.max_columns = None
final_data.head(-10)
# Out:
#                    CN_x  PLOT_x  INVYR_x  COUNTYCD_x        LAT         LON  \
# 0                 21116       3     2001           9  48.333954 -124.638580
# 1                 21116       3     2001           9  48.333954 -124.638580
# 2                 21116       3     2001           9  48.333954 -124.638580
# 3                 21116       3     2001           9  48.333954 -124.638580
# 4                 21116       3     2001           9  48.333954 -124.638580
# ...                 ...     ...      ...         ...        ...         ...
# 504941  786780593290487   94316     2021           7  47.773645 -120.626235
# 504942  786780593290487   94316     2021           7  47.773645 -120.626235
# 504943  786780593290487   94316     2021           7  47.773645 -120.626235
# 504944  786780593290487   94316     2021           7  47.773645 -120.626235
# 504945  786780595290487   82332     2021           3  46.234983 -117.356162
#
#           ELEV  MEASYEAR  MEASMON  MEASDAY              CN_y           PLT_CN  \
# 0        689.0      2000        8       29           4868680            21116
# 1        689.0      2000        8       29           4879268            21116
# 2        689.0      2000        8       29           4868701            21116
# 3        689.0      2000        8       29           4868700            21116
# 4        689.0      2000        8       29           4868699            21116
# ...        ...       ...      ...      ...               ...              ...
# 504941  2100.0      2021        7       30  1143395781290487  786780593290487
# 504942  2100.0      2021        7       30  1143395780290487  786780593290487
# 504943  2100.0      2021        7       30  1143395779290487  786780593290487
# 504944  2100.0      2021        7       30  1143395784290487  786780593290487
# 504945  3100.0      2021        9       28  1143395923290487  786780595290487
#
#         PREV_TRE_CN  INVYR_y  STATECD  UNITCD  COUNTYCD_y  PLOT_y  SUBP  \
# 0               NaN     2001       53       6           9       3     1
# 1               NaN     2001       53       6           9       3     3
# 2               NaN     2001       53       6           9       3     3
# 3               NaN     2001       53       6           9       3     3
# 4               NaN     2001       53       6           9       3     3
# ...             ...      ...      ...     ...         ...     ...   ...
# 504941          NaN     2021       53       8           7   94316     4
# 504942          NaN     2021       53       8           7   94316     3
# 504943          NaN     2021       53       8           7   94316     3
# 504944          NaN     2021       53       8           7   94316     4
# 504945          NaN     2021       53       9           3   82332     4
#
#            TREE  CONDID  PREVCOND  STATUSCD   SPCD  SPGRPCD   DIA  DIAHTCD  \
# 0       4868680       1       NaN         1  263.0       13  13.6      1.0
# 1       4879268       1       NaN         2  263.0       13  68.0      NaN
# 2       4868701       1       NaN         1  263.0       13   8.8      1.0
# 3       4868700       1       NaN         1  263.0       13   7.4      1.0
# 4       4868699       1       NaN         1  263.0       13   8.5      1.0
# ...         ...     ...       ...       ...    ...      ...   ...      ...
# 504941        1       2       NaN         2  202.0       10   5.3      1.0
# 504942        5       2       NaN         1   17.0       12   2.0      1.0
# 504943        4       2       NaN         1  202.0       10  12.8      1.0
# 504944        4       2       NaN         1  202.0       10  13.7      1.0
# 504945       12       2       NaN         2  202.0       10  14.1      1.0
#
#            HT  HTCD  ACTUALHT  TREECLCD    CR  CCLCD  TREEGRCD  AGENTCD  CULL  \
# 0        56.0   1.0       NaN       2.0  65.0    3.0       NaN      NaN   0.0
# 1       173.0   4.0      46.0       NaN   NaN    NaN       NaN      NaN   NaN
# 2        61.0   1.0       NaN       2.0   5.0    5.0       NaN      0.0   0.0
# 3        65.0   3.0       NaN       2.0  15.0    5.0       NaN     90.0   0.0
# 4        69.0   1.0       NaN       2.0  25.0    3.0       NaN      NaN   0.0
# ...       ...   ...       ...       ...   ...    ...       ...      ...   ...
# 504941   39.0   2.0      19.0       4.0   NaN    NaN       NaN      NaN   0.0
# 504942   10.0   1.0      10.0       2.0  99.0    3.0       NaN      NaN   NaN
# 504943   49.0   1.0      49.0       2.0  60.0    3.0       NaN      NaN   0.0
# 504944  105.0   1.0     105.0       2.0  25.0    3.0       NaN      NaN   0.0
# 504945   79.0   1.0      79.0       3.0   NaN    NaN       NaN      NaN   0.0
#
#         DAMLOC1  DAMTYP1  DAMSEV1  DAMLOC2  DAMTYP2  DAMSEV2  DECAYCD  \
# 0           NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1           NaN      NaN      NaN      NaN      NaN      NaN      5.0
# 2           NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3           NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4           NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...         ...      ...      ...      ...      ...      ...      ...
# 504941      NaN      NaN      NaN      NaN      NaN      NaN      3.0
# 504942      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 504943      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 504944      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 504945      NaN      NaN      NaN      NaN      NaN      NaN      1.0
#
#         STOCKING  WDLDSTEM    VOLCFNET    VOLCFGRS   VOLCSNET   VOLCSGRS  \
# 0         3.7087       NaN   22.796000   22.796000  22.038000  22.038000
# 1            NaN       NaN  585.292705  976.256113        NaN        NaN
# 2         1.5421       NaN   10.424000   10.424000        NaN        NaN
# 3         1.6329       NaN    7.484000    7.484000        NaN        NaN
# 4         4.2897       NaN   11.018000   11.018000        NaN        NaN
# ...          ...       ...         ...         ...        ...        ...
# 504941       NaN       NaN    1.590172    1.590172        NaN        NaN
# 504942    2.4576       NaN         NaN         NaN        NaN        NaN
# 504943    5.6622       NaN   13.592512   13.592512  11.893950  11.893950
# 504944    6.2868       NaN   38.460616   38.460616  35.352238  35.352238
# 504945       NaN       NaN   30.370246   30.370246        NaN        NaN
#
#           VOLBFNET    VOLBFGRS    VOLCFSND  DIACHECK  MORTYR  SALVCD  UNCRCD  \
# 0       118.135002  118.135002   22.796000       NaN     NaN     NaN     NaN
# 1              NaN         NaN  585.292705       NaN     NaN     NaN     NaN
# 2              NaN         NaN   10.424000       NaN     NaN     NaN     NaN
# 3              NaN         NaN    7.484000       NaN     NaN     NaN     NaN
# 4              NaN         NaN   11.018000       NaN     NaN     NaN     NaN
# ...            ...         ...         ...       ...     ...     ...     ...
# 504941         NaN         NaN    1.590172       0.0     NaN     NaN     NaN
# 504942         NaN         NaN         NaN       0.0     NaN     NaN     NaN
# 504943   56.541505   56.541505   13.592512       0.0     NaN     NaN     NaN
# 504944  214.261248  214.261248   38.460616       0.0     NaN     NaN     NaN
# 504945         NaN         NaN   30.370246       0.0     NaN     NaN     NaN
#
#         CPOSCD  CLIGHTCD  CVIGORCD  CDENCD  CDIEBKCD  TRANSCD  TREEHISTCD  \
# 0          NaN       NaN       NaN     NaN       NaN      NaN         NaN
# 1          NaN       NaN       NaN     NaN       NaN      NaN         NaN
# 2          NaN       NaN       NaN     NaN       NaN      NaN         NaN
# 3          NaN       NaN       NaN     NaN       NaN      NaN         NaN
# 4          NaN       NaN       NaN     NaN       NaN      NaN         NaN
# ...        ...       ...       ...     ...       ...      ...         ...
# 504941     NaN       NaN       NaN     NaN       NaN      NaN         NaN
# 504942     NaN       NaN       NaN     NaN       NaN      NaN         NaN
# 504943     NaN       NaN       NaN     NaN       NaN      NaN         NaN
# 504944     NaN       NaN       NaN     NaN       NaN      NaN         NaN
# 504945     NaN       NaN       NaN     NaN       NaN      NaN         NaN
#
#         BHAGE  TOTAGE  CULLDEAD  CULLFORM  CULLMSTOP  CULLBF  CULLCF  BFSND  \
# 0        36.0    44.0       NaN       NaN        NaN     NaN     NaN    NaN
# 1         NaN     NaN       NaN       NaN        NaN     NaN     NaN    NaN
# 2        39.0    47.0       NaN       NaN        NaN     NaN     NaN    NaN
# 3        39.0    47.0       NaN       NaN        NaN     NaN     NaN    NaN
# 4        39.0    47.0       NaN       NaN        NaN     NaN     NaN    NaN
# ...       ...     ...       ...       ...        ...     ...     ...    ...
# 504941    NaN     NaN       NaN       NaN        NaN     NaN     NaN    NaN
# 504942   10.0     NaN       NaN       NaN        NaN     NaN     NaN    NaN
# 504943   81.0     NaN       NaN       NaN        NaN     NaN     NaN    NaN
# 504944    NaN     NaN       NaN       NaN        NaN     NaN     NaN    NaN
# 504945    NaN     NaN       NaN       NaN        NaN     NaN     NaN    NaN
#
#         CFSND  SAWHT  BOLEHT  FORMCL  HTCALC  HRDWD_CLUMP_CD  SITREE  \
# 0         NaN    NaN     NaN     NaN     NaN             NaN     NaN
# 1         NaN    NaN     NaN     NaN     NaN             NaN     NaN
# 2         NaN    NaN     NaN     NaN     NaN             NaN     NaN
# 3         NaN    NaN     NaN     NaN     NaN             NaN     NaN
# 4         NaN    NaN     NaN     NaN     NaN             NaN     NaN
# ...       ...    ...     ...     ...     ...             ...     ...
# 504941    NaN    NaN     NaN     NaN     NaN             NaN     NaN
# 504942    NaN    NaN     NaN     NaN     NaN             NaN     NaN
# 504943    NaN    NaN     NaN     NaN     NaN             NaN     NaN
# 504944    NaN    NaN     NaN     NaN     NaN             NaN     NaN
# 504945    NaN    NaN     NaN     NaN     NaN             NaN     NaN
#
#                CREATED_DATE        MODIFIED_DATE  MORTCD  HTDMP  ROUGHCULL  \
# 0       2012-12-17 02:38:27  2024-09-17 18:06:31     NaN    NaN        NaN
# 1       2012-12-17 02:39:23  2024-09-17 18:06:31     NaN    NaN        NaN
# 2       2012-12-17 02:38:27  2024-09-17 18:06:31     NaN    NaN        NaN
# 3       2012-12-17 02:38:27  2024-09-17 18:06:31     NaN    NaN        NaN
# 4       2012-12-17 02:38:27  2024-09-17 18:06:31     NaN    NaN        NaN
# ...                     ...                  ...     ...    ...        ...
# 504941  2022-03-07 21:01:15  2024-09-17 18:06:24     NaN    NaN        NaN
# 504942  2022-03-07 21:01:15  2024-09-17 18:06:24     NaN    NaN        NaN
# 504943  2022-03-07 21:01:15  2024-09-17 18:06:24     NaN    NaN        0.0
# 504944  2022-03-07 21:01:15  2024-09-17 18:06:24     NaN    NaN        0.0
# 504945  2022-03-07 21:01:15  2024-09-17 18:06:16     NaN    NaN        NaN
#
#         MIST_CL_CD  CULL_FLD  RECONCILECD  PREVDIA P2A_GRM_FLG  TREECLCD_NERS  \
# 0              0.0       NaN          NaN      NaN         NaN            NaN
# 1              NaN       NaN          NaN      NaN         NaN            NaN
# 2              0.0       NaN          NaN      NaN         NaN            NaN
# 3              0.0       NaN          NaN      NaN         NaN            NaN
# 4              0.0       NaN          NaN      NaN         NaN            NaN
# ...            ...       ...          ...      ...         ...            ...
# 504941         NaN       0.0          NaN      NaN         NaN            NaN
# 504942         0.0       NaN          NaN      NaN         NaN            NaN
# 504943         5.0       0.0          NaN      NaN         NaN            NaN
# 504944         0.0       0.0          NaN      NaN         NaN            NaN
# 504945         NaN       0.0          NaN      NaN         NaN            NaN
#
#         TREECLCD_SRS  TREECLCD_NCRS  TREECLCD_RMRS  STANDING_DEAD_CD  \
# 0                NaN            NaN            NaN               NaN
# 1                NaN            NaN            NaN               NaN
# 2                NaN            NaN            NaN               NaN
# 3                NaN            NaN            NaN               NaN
# 4                NaN            NaN            NaN               NaN
# ...              ...            ...            ...               ...
# 504941           NaN            NaN            NaN               1.0
# 504942           NaN            NaN            NaN               NaN
# 504943           NaN            NaN            NaN               NaN
# 504944           NaN            NaN            NaN               NaN
# 504945           NaN            NaN            NaN               1.0
#
#         PREV_STATUS_CD  PREV_WDLDSTEM  TPA_UNADJ   DRYBIO_BOLE  DRYBIO_STUMP  \
# 0                  NaN            NaN  10.076000    597.437568     34.028706
# 1                  NaN            NaN   1.483999  15339.351213    387.020787
# 2                  NaN            NaN  24.065000    273.192192     19.711179
# 3                  NaN            NaN  34.032001    196.140672     15.606157
# 4                  NaN            NaN  25.792999    288.759744     21.242238
# ...                ...            ...        ...           ...           ...
# 504941             NaN            NaN   6.018046     37.493416      3.891018
# 504942             NaN            NaN  74.965282           NaN           NaN
# 504943             NaN            NaN   6.018046    327.683800     19.569345
# 504944             NaN            NaN   6.018046   1116.846790     31.816815
# 504945             NaN            NaN   6.018046    839.491297     31.404927
#
#           DRYBIO_BG     CARBON_AG    CARBON_BG  CYCLE  SUBCYCLE  \
# 0        196.609337    438.705030    99.680934      0       NaN
# 1       4778.867014  11324.672132  2518.462916      0       NaN
# 2         93.324404    205.128530    47.315473      0       NaN
# 3         68.357165    149.020726    34.657083      0       NaN
# 4         99.011304    217.296854    50.198731      0       NaN
# ...             ...           ...          ...    ...       ...
# 504941    14.808133     24.848276     7.492916      3       1.0
# 504942     1.413228      2.907912     0.679762      3       1.0
# 504943   124.133156    303.991043    64.052709      3       1.0
# 504944   349.565820    766.743798   180.375963      3       1.0
# 504945   267.236265    604.656988   133.885369      3       1.0
#
#         BORED_CD_PNWRS  DAMLOC1_PNWRS  DAMLOC2_PNWRS  DIACHECK_PNWRS  \
# 0                  NaN            NaN            NaN             NaN
# 1                  NaN            NaN            NaN             NaN
# 2                  1.0            NaN            NaN             NaN
# 3                  NaN            NaN            NaN             NaN
# 4                  NaN            NaN            NaN             NaN
# ...                ...            ...            ...             ...
# 504941             NaN            NaN            NaN             0.0
# 504942             1.0            NaN            NaN             0.0
# 504943             1.0            NaN            NaN             0.0
# 504944             NaN            NaN            NaN             0.0
# 504945             NaN            NaN            NaN             0.0
#
#         DMG_AGENT1_CD_PNWRS  DMG_AGENT2_CD_PNWRS  DMG_AGENT3_CD_PNWRS  \
# 0                       0.0                  0.0                  0.0
# 1                       NaN                  NaN                  NaN
# 2                      50.0                  0.0                  0.0
# 3                      95.0                  0.0                  0.0
# 4                       0.0                  0.0                  0.0
# ...                     ...                  ...                  ...
# 504941                  NaN                  NaN                  NaN
# 504942                  NaN                  NaN                  NaN
# 504943                  NaN                  NaN                  NaN
# 504944                  NaN                  NaN                  NaN
# 504945                  NaN                  NaN                  NaN
#
#         MIST_CL_CD_PNWRS  SEVERITY1_CD_PNWRS  SEVERITY1A_CD_PNWRS  \
# 0                    0.0                 NaN                  NaN
# 1                    NaN                 NaN                  NaN
# 2                    0.0                 0.0                  NaN
# 3                    0.0                 0.0                  NaN
# 4                    0.0                 NaN                  NaN
# ...                  ...                 ...                  ...
# 504941               NaN                 NaN                  NaN
# 504942               NaN                 NaN                  NaN
# 504943               NaN                 NaN                  NaN
# 504944               NaN                 NaN                  NaN
# 504945               NaN                 NaN                  NaN
#
#         SEVERITY1B_CD_PNWRS  SEVERITY2_CD_PNWRS  SEVERITY2A_CD_PNWRS  \
# 0                       NaN                 NaN                  NaN
# 1                       NaN                 NaN                  NaN
# 2                       NaN                 NaN                  NaN
# 3                       NaN                 NaN                  NaN
# 4                       NaN                 NaN                  NaN
# ...                     ...                 ...                  ...
# 504941                  NaN                 NaN                  NaN
# 504942                  NaN                 NaN                  NaN
# 504943                  NaN                 NaN                  NaN
# 504944                  NaN                 NaN                  NaN
# 504945                  NaN                 NaN                  NaN
#
#         SEVERITY2B_CD_PNWRS  SEVERITY3_CD_PNWRS  UNKNOWN_DAMTYP1_PNWRS  \
# 0                       NaN                 NaN                    NaN
# 1                       NaN                 NaN                    NaN
# 2                       NaN                 NaN                    NaN
# 3                       NaN                 NaN                    NaN
# 4                       NaN                 NaN                    NaN
# ...                     ...                 ...                    ...
# 504941                  NaN                 NaN                    NaN
# 504942                  NaN                 NaN                    NaN
# 504943                  NaN                 NaN                    NaN
# 504944                  NaN                 NaN                    NaN
# 504945                  NaN                 NaN                    NaN
#
#         UNKNOWN_DAMTYP2_PNWRS  PREV_PNTN_SRS  DISEASE_SRS  \
# 0                         NaN            NaN          NaN
# 1                         NaN            NaN          NaN
# 2                         NaN            NaN          NaN
# 3                         NaN            NaN          NaN
# 4                         NaN            NaN          NaN
# ...                       ...            ...          ...
# 504941                    NaN            NaN          NaN
# 504942                    NaN            NaN          NaN
# 504943                    NaN            NaN          NaN
# 504944                    NaN            NaN          NaN
# 504945                    NaN            NaN          NaN
#
#         DIEBACK_SEVERITY_SRS  DAMAGE_AGENT_CD1  DAMAGE_AGENT_CD2  \
# 0                        NaN               NaN               NaN
# 1                        NaN               NaN               NaN
# 2                        NaN               NaN               NaN
# 3                        NaN               NaN               NaN
# 4                        NaN               NaN               NaN
# ...                      ...               ...               ...
# 504941                   NaN               NaN               NaN
# 504942                   NaN               0.0               NaN
# 504943                   NaN           23023.0               0.0
# 504944                   NaN               0.0               NaN
# 504945                   NaN               NaN               NaN
#
#         DAMAGE_AGENT_CD3  CENTROID_DIA  CENTROID_DIA_HT  \
# 0                    NaN           NaN              NaN
# 1                    NaN           NaN              NaN
# 2                    NaN           NaN              NaN
# 3                    NaN           NaN              NaN
# 4                    NaN           NaN              NaN
# ...                  ...           ...              ...
# 504941               NaN           NaN              NaN
# 504942               NaN           NaN              NaN
# 504943               NaN           NaN              NaN
# 504944               NaN           NaN              NaN
# 504945               NaN           NaN              NaN
#
#         CENTROID_DIA_HT_ACTUAL  UPPER_DIA  UPPER_DIA_HT   VOLCSSND  \
# 0                          NaN        NaN           NaN        NaN
# 1                          NaN        NaN           NaN        NaN
# 2                          NaN        NaN           NaN        NaN
# 3                          NaN        NaN           NaN        NaN
# 4                          NaN        NaN           NaN        NaN
# ...                        ...        ...           ...        ...
# 504941                     NaN        NaN           NaN        NaN
# 504942                     NaN        NaN           NaN        NaN
# 504943                     NaN        NaN           NaN  11.893950
# 504944                     NaN        NaN           NaN  35.352238
# 504945                     NaN        NaN           NaN        NaN
#
#         DRYBIO_SAWLOG  DAMAGE_AGENT_CD1_SRS  DAMAGE_AGENT_CD2_SRS  \
# 0                 NaN                   NaN                   NaN
# 1                 NaN                   NaN                   NaN
# 2                 NaN                   NaN                   NaN
# 3                 NaN                   NaN                   NaN
# 4                 NaN                   NaN                   NaN
# ...               ...                   ...                   ...
# 504941            NaN                   NaN                   NaN
# 504942            NaN                   NaN                   NaN
# 504943     286.735441                   NaN                   NaN
# 504944    1026.583485                   NaN                   NaN
# 504945            NaN                   NaN                   NaN
#
#         DAMAGE_AGENT_CD3_SRS     DRYBIO_AG  ACTUALHT_CALC  ACTUALHT_CALC_CD  \
# 0                        NaN    865.295917            NaN               NaN
# 1                        NaN  21488.941425            NaN               NaN
# 2                        NaN    404.592761            NaN               NaN
# 3                        NaN    293.926481            NaN               NaN
# 4                        NaN    428.593399            NaN               NaN
# ...                      ...           ...            ...               ...
# 504941                   NaN     49.107265            NaN               NaN
# 504942                   NaN      6.045554            NaN               NaN
# 504943                   NaN    589.129928            NaN               NaN
# 504944                   NaN   1485.937592            NaN               NaN
# 504945                   NaN   1206.900175            NaN               NaN
#
#         CULL_BF_ROTTEN  CULL_BF_ROTTEN_CD  CULL_BF_ROUGH  CULL_BF_ROUGH_CD  \
# 0                  NaN                NaN            NaN               NaN
# 1                  NaN                NaN            NaN               NaN
# 2                  NaN                NaN            NaN               NaN
# 3                  NaN                NaN            NaN               NaN
# 4                  NaN                NaN            NaN               NaN
# ...                ...                ...            ...               ...
# 504941             NaN                NaN            NaN               NaN
# 504942             NaN                NaN            NaN               NaN
# 504943             NaN                NaN            NaN               NaN
# 504944             NaN                NaN            NaN               NaN
# 504945             NaN                NaN            NaN               NaN
#
#         PREVDIA_FLD  TREECLCD_31_NCRS  TREE_GRADE_NCRS  BOUGHS_AVAILABLE_NCRS  \
# 0               NaN               NaN              NaN                    NaN
# 1               NaN               NaN              NaN                    NaN
# 2               NaN               NaN              NaN                    NaN
# 3               NaN               NaN              NaN                    NaN
# 4               NaN               NaN              NaN                    NaN
# ...             ...               ...              ...                    ...
# 504941          NaN               NaN              NaN                    NaN
# 504942          NaN               NaN              NaN                    NaN
# 504943          NaN               NaN              NaN                    NaN
# 504944          NaN               NaN              NaN                    NaN
# 504945          NaN               NaN              NaN                    NaN
#
#         BOUGHS_HRVST_NCRS  TREECLCD_31_NERS  AGENTCD_NERS  BFSNDCD_NERS  \
# 0                     NaN               NaN           NaN           NaN
# 1                     NaN               NaN           NaN           NaN
# 2                     NaN               NaN           NaN           NaN
# 3                     NaN               NaN           NaN           NaN
# 4                     NaN               NaN           NaN           NaN
# ...                   ...               ...           ...           ...
# 504941                NaN               NaN           NaN           NaN
# 504942                NaN               NaN           NaN           NaN
# 504943                NaN               NaN           NaN           NaN
# 504944                NaN               NaN           NaN           NaN
# 504945                NaN               NaN           NaN           NaN
#
#         AGECHKCD_RMRS  PREV_ACTUALHT_RMRS  PREV_AGECHKCD_RMRS  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
# ...               ...                 ...                 ...
# 504941            NaN                 NaN                 NaN
# 504942            NaN                 NaN                 NaN
# 504943            NaN                 NaN                 NaN
# 504944            NaN                 NaN                 NaN
# 504945            NaN                 NaN                 NaN
#
#         PREV_BHAGE_RMRS  PREV_HT_RMRS  PREV_TOTAGE_RMRS  PREV_TREECLCD_RMRS  \
# 0                   NaN           NaN               NaN                 NaN
# 1                   NaN           NaN               NaN                 NaN
# 2                   NaN           NaN               NaN                 NaN
# 3                   NaN           NaN               NaN                 NaN
# 4                   NaN           NaN               NaN                 NaN
# ...                 ...           ...               ...                 ...
# 504941              NaN           NaN               NaN                 NaN
# 504942              NaN           NaN               NaN                 NaN
# 504943              NaN           NaN               NaN                 NaN
# 504944              NaN           NaN               NaN                 NaN
# 504945              NaN           NaN               NaN                 NaN
#
#         RADAGECD_RMRS  RADGRW_RMRS    VOLBSGRS    VOLBSNET  \
# 0                 NaN          NaN         NaN         NaN
# 1                 NaN          NaN         NaN         NaN
# 2                 NaN          NaN         NaN         NaN
# 3                 NaN          NaN         NaN         NaN
# 4                 NaN          NaN         NaN         NaN
# ...               ...          ...         ...         ...
# 504941            NaN          NaN         NaN         NaN
# 504942            NaN          NaN         NaN         NaN
# 504943            NaN          NaN   44.029557   44.029557
# 504944            NaN          NaN  178.101465  178.101465
# 504945            NaN          NaN         NaN         NaN
#
#         SAPLING_FUSIFORM_SRS  EPIPHYTE_PNWRS  ROOT_HT_PNWRS  CAVITY_USE_PNWRS  \
# 0                        NaN             NaN            NaN               NaN
# 1                        NaN             NaN            NaN               NaN
# 2                        NaN             NaN            NaN               NaN
# 3                        NaN             NaN            NaN               NaN
# 4                        NaN             NaN            NaN               NaN
# ...                      ...             ...            ...               ...
# 504941                   NaN             NaN            NaN               0.0
# 504942                   NaN             NaN            NaN               NaN
# 504943                   NaN             NaN            NaN               0.0
# 504944                   NaN             NaN            NaN               0.0
# 504945                   NaN             NaN            NaN               0.0
#
#         CORE_LENGTH_PNWRS  CULTURALLY_KILLED_PNWRS  DIA_EST_PNWRS GST_PNWRS  \
# 0                     NaN                      NaN            NaN       NaN
# 1                     NaN                      NaN            NaN       NaN
# 2                     NaN                      NaN            NaN       NaN
# 3                     NaN                      NaN            NaN       NaN
# 4                     NaN                      NaN            NaN       NaN
# ...                   ...                      ...            ...       ...
# 504941                NaN                      NaN            NaN       NaN
# 504942                NaN                      NaN            NaN       NaN
# 504943                NaN                      NaN            NaN       NaN
# 504944                NaN                      NaN            NaN       NaN
# 504945                NaN                      NaN            NaN       NaN
#
#         INC10YR_PNWRS  INC5YRHT_PNWRS  INC5YR_PNWRS  \
# 0                 NaN             NaN           NaN
# 1                 NaN             NaN           NaN
# 2                 NaN             NaN           NaN
# 3                 NaN             NaN           NaN
# 4                 NaN             NaN           NaN
# ...               ...             ...           ...
# 504941            NaN             NaN           NaN
# 504942            NaN             2.4           NaN
# 504943            3.0             NaN           1.0
# 504944            NaN             NaN           NaN
# 504945            NaN             NaN           NaN
#
#         RING_COUNT_INNER_2INCHES_PNWRS  RING_COUNT_PNWRS  SNAG_DIS_CD_PNWRS  \
# 0                                  NaN               NaN                NaN
# 1                                  NaN               NaN                NaN
# 2                                  NaN               NaN                NaN
# 3                                  NaN               NaN                NaN
# 4                                  NaN               NaN                NaN
# ...                                ...               ...                ...
# 504941                             NaN               NaN                NaN
# 504942                             NaN               NaN                NaN
# 504943                             NaN               NaN                NaN
# 504944                             NaN               NaN                NaN
# 504945                             NaN               NaN                NaN
#
#         CONEPRESCD1  CONEPRESCD2  CONEPRESCD3  MASTCD   VOLTSGRS  \
# 0               NaN          NaN          NaN     NaN        NaN
# 1               NaN          NaN          NaN     NaN        NaN
# 2               NaN          NaN          NaN     NaN        NaN
# 3               NaN          NaN          NaN     NaN        NaN
# 4               NaN          NaN          NaN     NaN        NaN
# ...             ...          ...          ...     ...        ...
# 504941          NaN          NaN          NaN     NaN   2.426842
# 504942          NaN          NaN          NaN     NaN   0.125763
# 504943          NaN          NaN          NaN     NaN  14.718652
# 504944          NaN          NaN          NaN     NaN  40.128948
# 504945          NaN          NaN          NaN     NaN  31.924586
#
#         VOLTSGRS_BARK   VOLTSSND  VOLTSSND_BARK  VOLCFGRS_STUMP  \
# 0                 NaN        NaN            NaN             NaN
# 1                 NaN        NaN            NaN             NaN
# 2                 NaN        NaN            NaN             NaN
# 3                 NaN        NaN            NaN             NaN
# 4                 NaN        NaN            NaN             NaN
# ...               ...        ...            ...             ...
# 504941       0.583455   1.903973       0.228874        0.165026
# 504942       0.064070   0.125763       0.064070             NaN
# 504943       4.088278  14.718652       4.088278        0.811748
# 504944       8.695756  40.128948       8.695756        1.095669
# 504945       7.220965  31.924586       7.220965        1.136135
#
#         VOLCFGRS_STUMP_BARK  VOLCFSND_STUMP  VOLCFSND_STUMP_BARK  \
# 0                       NaN             NaN                  NaN
# 1                       NaN             NaN                  NaN
# 2                       NaN             NaN                  NaN
# 3                       NaN             NaN                  NaN
# 4                       NaN             NaN                  NaN
# ...                     ...             ...                  ...
# 504941             0.039675        0.165026             0.019838
# 504942                  NaN             NaN                  NaN
# 504943             0.225472        0.811748             0.225472
# 504944             0.237426        1.095669             0.237426
# 504945             0.256980        1.136135             0.256980
#
#         VOLCFGRS_BARK  VOLCFGRS_TOP  VOLCFGRS_TOP_BARK  VOLCFSND_BARK  \
# 0                 NaN           NaN                NaN            NaN
# 1                 NaN           NaN                NaN            NaN
# 2                 NaN           NaN                NaN            NaN
# 3                 NaN           NaN                NaN            NaN
# 4                 NaN           NaN                NaN            NaN
# ...               ...           ...                ...            ...
# 504941       0.382305      0.671644           0.161475       0.191153
# 504942            NaN           NaN                NaN            NaN
# 504943       3.775480      0.314392           0.087326       3.775480
# 504944       8.334236      0.572663           0.124093       8.334236
# 504945       6.869392      0.418205           0.094593       6.869392
#
#         VOLCFSND_TOP  VOLCFSND_TOP_BARK  VOLCFNET_BARK  VOLCSGRS_BARK  \
# 0                NaN                NaN            NaN            NaN
# 1                NaN                NaN            NaN            NaN
# 2                NaN                NaN            NaN            NaN
# 3                NaN                NaN            NaN            NaN
# 4                NaN                NaN            NaN            NaN
# ...              ...                ...            ...            ...
# 504941      0.148775           0.017884       0.095576            NaN
# 504942           NaN                NaN            NaN            NaN
# 504943      0.314392           0.087326       3.775480       3.303684
# 504944      0.572663           0.124093       8.334236       7.660665
# 504945      0.418205           0.094593       6.869392            NaN
#
#         VOLCSSND_BARK  VOLCSNET_BARK  DRYBIO_STEM  DRYBIO_STEM_BARK  \
# 0                 NaN            NaN          NaN               NaN
# 1                 NaN            NaN          NaN               NaN
# 2                 NaN            NaN          NaN               NaN
# 3                 NaN            NaN          NaN               NaN
# 4                 NaN            NaN          NaN               NaN
# ...               ...            ...          ...               ...
# 504941            NaN            NaN    44.892277          4.214987
# 504942            NaN            NaN     2.269956          0.605525
# 504943       3.303684       3.303684   354.832407         68.177240
# 504944       7.660665       7.660665  1165.293002        172.420281
# 504945            NaN            NaN   882.456205        155.722170
#
#         DRYBIO_STUMP_BARK  DRYBIO_BOLE_BARK  DRYBIO_BRANCH  DRYBIO_FOLIAGE  \
# 0                6.400638        112.375162            NaN             NaN
# 1               72.796767       2885.258919            NaN             NaN
# 2                3.707579         51.386150            NaN             NaN
# 3                2.935444         36.893126            NaN             NaN
# 4                3.995564         54.314333            NaN             NaN
# ...                   ...               ...            ...             ...
# 504941           0.365332          3.520300       0.000000        0.000000
# 504942                NaN               NaN       3.170074        5.129682
# 504943           3.760040         62.960927     166.120281       92.997656
# 504944           4.707712        165.252033     148.224308       39.102186
# 504945           5.541854        148.140390     168.721800        0.000000
#
#         DRYBIO_SAWLOG_BARK
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 504941                 NaN
# 504942                 NaN
# 504943           55.093139
# 504944          151.896401
# 504945                 NaN
#
# [504946 rows x 205 columns]

# %%
#dropping unnecessary features
final_data = final_data.drop(columns = ['CN_x', 'PLOT_x', 'COUNTYCD_x', 'INVYR_x']) #dropping duplicate features
final_data = final_data.dropna(axis = 1, how = 'all') #drops columns that are completely empty.

# %%
#renaming remaining columns from duplicate features
final_data = final_data.rename(columns={'PLOT_y':'PLOT', 'COUNTYCD_y':'COUNTYCD', 'INVYR_y':'INVRY', 'CN_y':'CN'})

# %%
final_data.info(verbose=True, show_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504956 entries, 0 to 504955
# Data columns (total 144 columns):
#  #    Column                          Non-Null Count   Dtype
# ---   ------                          --------------   -----
#  0    LAT                             504956 non-null  float64
#  1    LON                             504956 non-null  float64
#  2    ELEV                            504956 non-null  float64
#  3    MEASYEAR                        504956 non-null  int64
#  4    MEASMON                         504956 non-null  int64
#  5    MEASDAY                         504956 non-null  int64
#  6    CN                              504956 non-null  int64
#  7    PLT_CN                          504956 non-null  int64
#  8    PREV_TRE_CN                     224226 non-null  float64
#  9    INVRY                           504956 non-null  int64
#  10   STATECD                         504956 non-null  int64
#  11   UNITCD                          504956 non-null  int64
#  12   COUNTYCD                        504956 non-null  int64
#  13   PLOT                            504956 non-null  int64
#  14   SUBP                            504956 non-null  int64
#  15   TREE                            504956 non-null  int64
#  16   CONDID                          504956 non-null  int64
#  17   PREVCOND                        264161 non-null  float64
#  18   STATUSCD                        504956 non-null  int64
#  19   SPCD                            504956 non-null  float64
#  20   SPGRPCD                         504956 non-null  int64
#  21   DIA                             464134 non-null  float64
#  22   DIAHTCD                         503725 non-null  float64
#  23   HT                              464134 non-null  float64
#  24   HTCD                            464068 non-null  float64
#  25   ACTUALHT                        451535 non-null  float64
#  26   TREECLCD                        463367 non-null  float64
#  27   CR                              390859 non-null  float64
#  28   CCLCD                           390859 non-null  float64
#  29   AGENTCD                         44337 non-null   float64
#  30   CULL                            397054 non-null  float64
#  31   DAMLOC1                         94022 non-null   float64
#  32   DAMTYP1                         1835 non-null    float64
#  33   DAMSEV1                         1835 non-null    float64
#  34   DAMLOC2                         26918 non-null   float64
#  35   DAMTYP2                         282 non-null     float64
#  36   DAMSEV2                         282 non-null     float64
#  37   DECAYCD                         73275 non-null   float64
#  38   STOCKING                        389940 non-null  float64
#  39   WDLDSTEM                        800 non-null     float64
#  40   VOLCFNET                        418905 non-null  float64
#  41   VOLCFGRS                        418905 non-null  float64
#  42   VOLCSNET                        192408 non-null  float64
#  43   VOLCSGRS                        192408 non-null  float64
#  44   VOLBFNET                        192408 non-null  float64
#  45   VOLBFGRS                        192408 non-null  float64
#  46   VOLCFSND                        418905 non-null  float64
#  47   DIACHECK                        450311 non-null  float64
#  48   MORTYR                          39102 non-null   float64
#  49   UNCRCD                          5524 non-null    float64
#  50   CPOSCD                          5524 non-null    float64
#  51   CLIGHTCD                        5524 non-null    float64
#  52   CVIGORCD                        586 non-null     float64
#  53   CDENCD                          4938 non-null    float64
#  54   CDIEBKCD                        4938 non-null    float64
#  55   TRANSCD                         4938 non-null    float64
#  56   BHAGE                           113770 non-null  float64
#  57   TOTAGE                          11994 non-null   float64
#  58   FORMCL                          23982 non-null   float64
#  59   HTCALC                          221884 non-null  float64
#  60   HRDWD_CLUMP_CD                  13183 non-null   float64
#  61   CREATED_DATE                    504956 non-null  object
#  62   MODIFIED_DATE                   504956 non-null  object
#  63   HTDMP                           2063 non-null    float64
#  64   ROUGHCULL                       333009 non-null  float64
#  65   MIST_CL_CD                      356516 non-null  float64
#  66   CULL_FLD                        384455 non-null  float64
#  67   RECONCILECD                     49072 non-null   float64
#  68   PREVDIA                         224181 non-null  float64
#  69   P2A_GRM_FLG                     248651 non-null  object
#  70   STANDING_DEAD_CD                95535 non-null   float64
#  71   PREV_STATUS_CD                  224818 non-null  float64
#  72   PREV_WDLDSTEM                   806 non-null     float64
#  73   TPA_UNADJ                       464142 non-null  float64
#  74   DRYBIO_BOLE                     418905 non-null  float64
#  75   DRYBIO_STUMP                    418905 non-null  float64
#  76   DRYBIO_BG                       464134 non-null  float64
#  77   CARBON_AG                       464075 non-null  float64
#  78   CARBON_BG                       464134 non-null  float64
#  79   CYCLE                           504956 non-null  int64
#  80   SUBCYCLE                        491126 non-null  float64
#  81   BORED_CD_PNWRS                  103968 non-null  float64
#  82   DAMLOC1_PNWRS                   154264 non-null  float64
#  83   DAMLOC2_PNWRS                   55511 non-null   float64
#  84   DIACHECK_PNWRS                  450311 non-null  float64
#  85   DMG_AGENT1_CD_PNWRS             123375 non-null  float64
#  86   DMG_AGENT2_CD_PNWRS             84087 non-null   float64
#  87   DMG_AGENT3_CD_PNWRS             67832 non-null   float64
#  88   MIST_CL_CD_PNWRS                49708 non-null   float64
#  89   SEVERITY1_CD_PNWRS              21402 non-null   float64
#  90   SEVERITY1A_CD_PNWRS             55511 non-null   float64
#  91   SEVERITY1B_CD_PNWRS             163 non-null     float64
#  92   SEVERITY2_CD_PNWRS              5734 non-null    float64
#  93   SEVERITY2A_CD_PNWRS             16254 non-null   float64
#  94   SEVERITY2B_CD_PNWRS             82 non-null      float64
#  95   SEVERITY3_CD_PNWRS              1767 non-null    float64
#  96   UNKNOWN_DAMTYP1_PNWRS           7364 non-null    float64
#  97   UNKNOWN_DAMTYP2_PNWRS           2863 non-null    float64
#  98   DAMAGE_AGENT_CD1                168479 non-null  float64
#  99   DAMAGE_AGENT_CD2                40424 non-null   float64
#  100  DAMAGE_AGENT_CD3                12136 non-null   float64
#  101  VOLCSSND                        184222 non-null  float64
#  102  DRYBIO_SAWLOG                   184222 non-null  float64
#  103  DRYBIO_AG                       464075 non-null  float64
#  104  PREVDIA_FLD                     223603 non-null  float64
#  105  PREV_HT_RMRS                    2011 non-null    float64
#  106  VOLBSGRS                        184222 non-null  float64
#  107  VOLBSNET                        184222 non-null  float64
#  108  CAVITY_USE_PNWRS                407743 non-null  float64
#  109  CORE_LENGTH_PNWRS               894 non-null     float64
#  110  CULTURALLY_KILLED_PNWRS         29375 non-null   float64
#  111  DIA_EST_PNWRS                   874 non-null     float64
#  112  GST_PNWRS                       126297 non-null  object
#  113  INC10YR_PNWRS                   48248 non-null   float64
#  114  INC5YRHT_PNWRS                  5577 non-null    float64
#  115  INC5YR_PNWRS                    48419 non-null   float64
#  116  RING_COUNT_INNER_2INCHES_PNWRS  893 non-null     float64
#  117  RING_COUNT_PNWRS                893 non-null     float64
#  118  SNAG_DIS_CD_PNWRS               12575 non-null   float64
#  119  VOLTSGRS                        450245 non-null  float64
#  120  VOLTSGRS_BARK                   449504 non-null  float64
#  121  VOLTSSND                        450245 non-null  float64
#  122  VOLTSSND_BARK                   449504 non-null  float64
#  123  VOLCFGRS_STUMP                  407161 non-null  float64
#  124  VOLCFGRS_STUMP_BARK             407161 non-null  float64
#  125  VOLCFSND_STUMP                  407161 non-null  float64
#  126  VOLCFSND_STUMP_BARK             407161 non-null  float64
#  127  VOLCFGRS_BARK                   407161 non-null  float64
#  128  VOLCFGRS_TOP                    407161 non-null  float64
#  129  VOLCFGRS_TOP_BARK               407161 non-null  float64
#  130  VOLCFSND_BARK                   407161 non-null  float64
#  131  VOLCFSND_TOP                    407161 non-null  float64
#  132  VOLCFSND_TOP_BARK               407161 non-null  float64
#  133  VOLCFNET_BARK                   407161 non-null  float64
#  134  VOLCSGRS_BARK                   184222 non-null  float64
#  135  VOLCSSND_BARK                   184222 non-null  float64
#  136  VOLCSNET_BARK                   184222 non-null  float64
#  137  DRYBIO_STEM                     449504 non-null  float64
#  138  DRYBIO_STEM_BARK                449504 non-null  float64
#  139  DRYBIO_STUMP_BARK               418905 non-null  float64
#  140  DRYBIO_BOLE_BARK                418905 non-null  float64
#  141  DRYBIO_BRANCH                   449504 non-null  float64
#  142  DRYBIO_FOLIAGE                  450277 non-null  float64
#  143  DRYBIO_SAWLOG_BARK              184222 non-null  float64
# dtypes: float64(124), int64(16), object(4)
# memory usage: 554.8+ MB

# %%
#saving current dataset -- Make sure you do a run all after any further changes as of 1:01 pm CDT 10/31/24

# df.to_csv('folder/subfolder/out.csv')   --- from pandas docs

final_data.to_csv('/Users/ellapalacios/Downloads/tree_proj/data/final_data.csv')
