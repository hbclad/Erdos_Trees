# %% [markdown]
# **Introduction**
# The following document includes some analysis of the TREES dataset from the FIA Datamart.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
sns.set_style("whitegrid")

# %%
wa_tree_data =pd.read_csv('../Data/WA_TREE.csv')
# Out:
# /var/folders/rd/2pn3c7gx2_9_cbdrsq0k0r6r0000gn/T/ipykernel_33222/1207950250.py:1: DtypeWarning: Columns (77,159) have mixed types. Specify dtype option on import or set low_memory=False.
#   wa_tree_data =pd.read_csv('../Data/WA_TREE.csv')

# %%
WA_Tree_Health=wa_tree_data[['CN','PLT_CN','PREV_TRE_CN','INVYR','STATUSCD','TPA_UNADJ','STOCKING','HT','DIA','CR','BHAGE','CDENCD','CULL_FLD']]

# %% [markdown]
# StatusCd =
# - 0:no status (tree not presently in sample?)
# - 1: live tree
# - 2: dead tree
# - 3: removed (tree removed by humans)

# %%
WA_Tree_Health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504956 entries, 0 to 504955
# Data columns (total 13 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   CN           504956 non-null  int64
#  1   PLT_CN       504956 non-null  int64
#  2   PREV_TRE_CN  224226 non-null  float64
#  3   INVYR        504956 non-null  int64
#  4   STATUSCD     504956 non-null  int64
#  5   TPA_UNADJ    464142 non-null  float64
#  6   STOCKING     389940 non-null  float64
#  7   HT           464134 non-null  float64
#  8   DIA          464134 non-null  float64
#  9   CR           390859 non-null  float64
#  10  BHAGE        113770 non-null  float64
#  11  CDENCD       4938 non-null    float64
#  12  CULL_FLD     384455 non-null  float64
# dtypes: float64(9), int64(4)
# memory usage: 50.1 MB

# %%
plt.hist(WA_Tree_Health['STATUSCD'],bins=27)
plt.show()

# %%
plt.hist(WA_Tree_Health['TPA_UNADJ'],bins=50)
plt.show()

plt.hist(WA_Tree_Health['STOCKING'],bins=50)
plt.show()

# %%
WA_Tree_Health.sample(20)
# Out:
#                      CN           PLT_CN   PREV_TRE_CN  INVYR  STATUSCD  \
# 436708  720600292290487  558629448126144  7.834500e+11   2019         2
# 253335  177571716020004   30852519020004  2.242067e+13   2012         1
# 156551     803122010497   29395650010497           NaN   2008         1
# 285246  248713771489998  174763583020004  2.241315e+13   2013         2
# 332199  374637890489998  290008704489998  2.240896e+13   2015         2
# 273570  248779888489998  174764012020004  2.242378e+13   2013         1
# 310538  302264356489998  216959256020004  2.483028e+13   2014         3
# 85580    22416536010497   22398916010497           NaN   2005         1
# 363347  451030983489998  346864040489998           NaN   2016         1
# 471982  850462433290487  645308768126144  1.508652e+13   2020         2
# 178222     784991010497   29883433010497           NaN   2009         1
# 469915  850534853290487  714229297290487  1.574809e+13   2020         2
# 269987  248895414489998   44542655020004  2.452913e+13   2013         1
# 265636  248931630489998   44543554020004           NaN   2013         1
# 83337    22450281010497   22399069010497           NaN   2005         2
# 84733    12973889010497   12973613010497           NaN   2005         1
# 238346  177538568020004   30764778020004           NaN   2012         1
# 333584  374572379489998  273641521489998  1.296643e+13   2015         1
# 41156    22417629010497   22398459010497           NaN   2003         1
# 425558  720632690290487  558629196126144  1.543993e+13   2019         2
#
#         TPA_UNADJ  STOCKING
# 436708        NaN       NaN
# 253335   6.018046    1.4745
# 156551   6.018046    2.1313
# 285246   0.999188       NaN
# 332199        NaN       NaN
# 273570   0.999188    2.1839
# 310538        NaN       NaN
# 85580    6.018046    2.7590
# 363347  74.965282    0.0818
# 471982   6.018046       NaN
# 178222   6.018046    1.0516
# 469915   6.018046       NaN
# 269987   6.018046    0.0663
# 265636   6.018046    1.2538
# 83337    6.018046       NaN
# 84733    6.018046   19.6859
# 238346   0.999188    1.2919
# 333584   6.018046    0.4009
# 41156    0.999188    2.0377
# 425558        NaN       NaN
